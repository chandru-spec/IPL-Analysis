# %% [markdown]
# # CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
a=pd.read_csv("Documents/odi-batting.csv")

# %%
a.isna().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# ScoreRate    26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55926 entries, 0 to 55925
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    55926 non-null  object
#  1   Player     55926 non-null  object
#  2   Runs       55900 non-null  float64
#  3   ScoreRate  55900 non-null  float64
#  4   MatchDate  55926 non-null  object
#  5   Ground     55926 non-null  object
#  6   Versus     55926 non-null  object
#  7   URL        55926 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 3.4+ MB

# %%
a.describe()
# Out:
#                Runs     ScoreRate
# count  55900.000000  55900.000000
# mean      22.241413     65.314208
# std       25.558363     44.213423
# min        0.000000      0.000000
# 25%        4.000000     37.500000
# 50%       13.000000     62.660000
# 75%       32.000000     87.500000
# max      200.000000    600.000000

# %%
a.shape
# Out:
# (55926, 8)

# %%
a.head()
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %%
a.head(20)
# Out:
#         Country            Player   Runs  ScoreRate   MatchDate  \
# 0   Afghanistan  Mohammad Shahzad  118.0      97.52   2-16-2010
# 1   Afghanistan  Mohammad Shahzad  110.0      99.09    9-1-2009
# 2   Afghanistan  Mohammad Shahzad  100.0     138.88   8-16-2010
# 3   Afghanistan  Mohammad Shahzad   82.0      75.92   7-10-2010
# 4   Afghanistan  Mohammad Shahzad   57.0     100.00    7-1-2010
# 5   Afghanistan  Mohammad Shahzad   55.0      87.30    7-7-2010
# 6   Afghanistan  Mohammad Shahzad   37.0      80.43   10-9-2010
# 7   Afghanistan  Mohammad Shahzad   34.0      77.27    7-9-2010
# 8   Afghanistan  Mohammad Shahzad   20.0      90.90    7-5-2010
# 9   Afghanistan  Mohammad Shahzad   16.0      57.14   8-30-2009
# 10  Afghanistan  Mohammad Shahzad   11.0     100.00   8-17-2010
# 11  Afghanistan  Mohammad Shahzad    8.0      80.00    8-9-2011
# 12  Afghanistan  Mohammad Shahzad    2.0      50.00    7-3-2010
# 13  Afghanistan  Mohammad Shahzad    1.0      25.00   10-7-2010
# ...

# %%
a.tail()
# Out:
#         Country               Player  Runs  ScoreRate   MatchDate  \
# 55921  Zimbabwe  Waddington Mwayenga   0.0        0.0   5-27-2004
# 55922  Zimbabwe   Tafadzwa Kamungozi   0.0        0.0  10-10-2006
# 55923  Zimbabwe   Tafadzwa Kamungozi   0.0        0.0   10-8-2006
# 55924  Zimbabwe   Tafadzwa Kamungozi   0.0        0.0  10-13-2006
# 55925  Zimbabwe        Njabulo Ncube   0.0        0.0  10-25-2011
#
#                        Ground       Versus  \
# 55921      Harare Sports Club    Australia
# 55922    Sardar Patel Stadium    Sri Lanka
# 55923    Sardar Patel Stadium  West Indies
# 55924  Sawai Mansingh Stadium   Bangladesh
# 55925      Queens Sports Club  New Zealand
#
#                                                     URL
# 55921  ../Matches/MatchScorecard_ODI.asp?MatchCode=2226
# 55922  ../Matches/MatchScorecard_ODI.asp?MatchCode=2529
# 55923  ../Matches/MatchScorecard_ODI.asp?MatchCode=2528
# 55924  ../Matches/MatchScorecard_ODI.asp?MatchCode=2531
# ...

# %%
a.tail(20)
# Out:
#         Country                Player  Runs  ScoreRate   MatchDate  \
# 55906  Zimbabwe         Alan C I Lock   5.0      45.45    3-1-1996
# 55907  Zimbabwe  Everton Matambanadzo   5.0      23.80    4-9-1997
# 55908  Zimbabwe         Alan C I Lock   2.0      50.00    3-6-1996
# 55909  Zimbabwe  Everton Matambanadzo   2.0      66.66   11-3-1996
# 55910  Zimbabwe         Alan C I Lock   1.0      20.00   2-16-1996
# 55911  Zimbabwe  Everton Matambanadzo   1.0      50.00    4-8-1997
# 55912  Zimbabwe  Everton Matambanadzo   0.0       0.00    4-3-1997
# 55913  Zimbabwe  Everton Matambanadzo   0.0       0.00    4-6-1997
# 55914  Zimbabwe        Vincent R Hogg   7.0      36.84   6-16-1983
# 55915  Zimbabwe      Natsai Mushangwe   7.0      70.00  10-25-2011
# 55916  Zimbabwe         Kevin G Duers   5.0      50.00   3-10-1992
# 55917  Zimbabwe         Kevin G Duers   2.0      20.00   3-14-1992
# 55918  Zimbabwe         Ujesh Ranchod   3.0      50.00    2-3-1993
# ...

# %%
a.loc[20:30]
# Out:
#         Country         Player  Runs  ScoreRate  MatchDate  \
# 20  Afghanistan  Mohammad Nabi  47.0     111.90   7-5-2010
# 21  Afghanistan  Mohammad Nabi  47.0     151.61   8-9-2011
# 22  Afghanistan  Mohammad Nabi  23.0      92.00   7-3-2010
# 23  Afghanistan  Mohammad Nabi  23.0     127.77  10-9-2010
# 24  Afghanistan  Mohammad Nabi  15.0     125.00   7-1-2010
# 25  Afghanistan  Mohammad Nabi   8.0     160.00   9-1-2009
# 26  Afghanistan  Mohammad Nabi   8.0      61.53  8-30-2009
# 27  Afghanistan  Mohammad Nabi   8.0     160.00  2-16-2010
# 28  Afghanistan  Mohammad Nabi   6.0      46.15  7-10-2010
# 29  Afghanistan  Mohammad Nabi   4.0      26.66   7-9-2010
# 30  Afghanistan  Mohammad Nabi   2.0      25.00  8-17-2010
#
#                              Ground       Versus  \
# 20                       VRA Ground        Kenya
# 21  Cricket, Skating & Curling Club       Canada
# 22                      Hazelaarweg      Ireland
# 23             Gymkhana Club Ground        Kenya
# ...

# %%
a.loc[20:30,"Runs"]
# Out:
# 20    47.0
# 21    47.0
# 22    23.0
# 23    23.0
# 24    15.0
# 25     8.0
# 26     8.0
# 27     8.0
# 28     6.0
# 29     4.0
# 30     2.0
# Name: Runs, dtype: float64

# %%
a.iloc[20:30]
# Out:
#         Country         Player  Runs  ScoreRate  MatchDate  \
# 20  Afghanistan  Mohammad Nabi  47.0     111.90   7-5-2010
# 21  Afghanistan  Mohammad Nabi  47.0     151.61   8-9-2011
# 22  Afghanistan  Mohammad Nabi  23.0      92.00   7-3-2010
# 23  Afghanistan  Mohammad Nabi  23.0     127.77  10-9-2010
# 24  Afghanistan  Mohammad Nabi  15.0     125.00   7-1-2010
# 25  Afghanistan  Mohammad Nabi   8.0     160.00   9-1-2009
# 26  Afghanistan  Mohammad Nabi   8.0      61.53  8-30-2009
# 27  Afghanistan  Mohammad Nabi   8.0     160.00  2-16-2010
# 28  Afghanistan  Mohammad Nabi   6.0      46.15  7-10-2010
# 29  Afghanistan  Mohammad Nabi   4.0      26.66   7-9-2010
#
#                              Ground       Versus  \
# 20                       VRA Ground        Kenya
# 21  Cricket, Skating & Curling Club       Canada
# 22                      Hazelaarweg      Ireland
# 23             Gymkhana Club Ground        Kenya
# 24              Sportpark Westvliet       Canada
# ...

# %%
a.iloc[20:30,1]
# Out:
# 20    Mohammad Nabi
# 21    Mohammad Nabi
# 22    Mohammad Nabi
# 23    Mohammad Nabi
# 24    Mohammad Nabi
# 25    Mohammad Nabi
# 26    Mohammad Nabi
# 27    Mohammad Nabi
# 28    Mohammad Nabi
# 29    Mohammad Nabi
# Name: Player, dtype: object

# %%
a.iloc[1,:]
# Out:
# Country                                           Afghanistan
# Player                                       Mohammad Shahzad
# Runs                                                    110.0
# ScoreRate                                               99.09
# MatchDate                                            9-1-2009
# Ground                                             VRA Ground
# Versus                                            Netherlands
# URL          ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# Name: 1, dtype: object

# %%
a.iloc[:,1]
# Out:
# 0           Mohammad Shahzad
# 1           Mohammad Shahzad
# 2           Mohammad Shahzad
# 3           Mohammad Shahzad
# 4           Mohammad Shahzad
#                 ...
# 55921    Waddington Mwayenga
# 55922     Tafadzwa Kamungozi
# 55923     Tafadzwa Kamungozi
# 55924     Tafadzwa Kamungozi
# 55925          Njabulo Ncube
# Name: Player, Length: 55926, dtype: object

# %%
a["Runs"]
# Out:
# 0        118.0
# 1        110.0
# 2        100.0
# 3         82.0
# 4         57.0
#          ...
# 55921      0.0
# 55922      0.0
# 55923      0.0
# 55924      0.0
# 55925      0.0
# Name: Runs, Length: 55926, dtype: float64

# %%
a["Runs"].value_counts()
# Out:
# 0.0      5613
# 1.0      3402
# 2.0      2576
# 4.0      2062
# 3.0      2031
#          ...
# 166.0       1
# 177.0       1
# 159.0       1
# 185.0       1
# 178.0       1
# Name: Runs, Length: 180, dtype: int64

# %%
a[(a["Runs"]>100)]
# Out:
#            Country              Player   Runs  ScoreRate   MatchDate  \
# 0      Afghanistan    Mohammad Shahzad  118.0      97.52   2-16-2010
# 1      Afghanistan    Mohammad Shahzad  110.0      99.09    9-1-2009
# 66     Afghanistan     Noor Ali Zadran  114.0      89.76   2-16-2010
# 91     Afghanistan        Karim Sadiq   114.0     105.55   8-16-2010
# 161      Australia     Ricky T Ponting  164.0     156.19   3-12-2006
# ...            ...                 ...    ...        ...         ...
# 53989     Zimbabwe      Neil C Johnson  103.0      85.83  11-22-1998
# 53990     Zimbabwe      Neil C Johnson  101.0      84.16   3-23-1999
# 54035     Zimbabwe    David L Houghton  142.0     103.64  10-10-1987
# 54095     Zimbabwe      Dion D Ebrahim  121.0      86.42  11-25-2001
# 54505     Zimbabwe  Charles K Coventry  194.0     124.35   8-16-2009
#
#                              Ground        Versus  \
# 0                Sharjah CA Stadium        Canada
# ...

# %%
a.isna().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# ScoreRate    26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %%
a.iloc[g["Runs"].isna()]=78

# %%
a.iloc[g["ScoreRate"].isna()]=300

# %%
a.isna().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %% [markdown]
# # INDEXING

# %%
a.set_index("Runs",inplace=True)

# %%
a
# Out:
#            Country               Player   MatchDate                  Ground  \
# Runs
# 118.0  Afghanistan     Mohammad Shahzad   2-16-2010      Sharjah CA Stadium
# 110.0  Afghanistan     Mohammad Shahzad    9-1-2009              VRA Ground
# 100.0  Afghanistan     Mohammad Shahzad   8-16-2010   Cambusdoon New Ground
# 82.0   Afghanistan     Mohammad Shahzad   7-10-2010             Hazelaarweg
# 57.0   Afghanistan     Mohammad Shahzad    7-1-2010     Sportpark Westvliet
# ...            ...                  ...         ...                     ...
# 0.0       Zimbabwe  Waddington Mwayenga   5-27-2004      Harare Sports Club
# 0.0       Zimbabwe   Tafadzwa Kamungozi  10-10-2006    Sardar Patel Stadium
# 0.0       Zimbabwe   Tafadzwa Kamungozi   10-8-2006    Sardar Patel Stadium
# 0.0       Zimbabwe   Tafadzwa Kamungozi  10-13-2006  Sawai Mansingh Stadium
# 0.0       Zimbabwe        Njabulo Ncube  10-25-2011      Queens Sports Club
#
# ...

# %%
a.reset_index(inplace=True)

# %%
e=a.groupby("MatchDate")

# %%
e

# %%
e=a.groupby("MatchDate")[["Ground"]].count()

# %%
e
# Out:
#            Ground
# MatchDate
# 1-1-1975       20
# 1-1-1987       19
# 1-1-1989       16
# 1-1-1991       20
# 1-1-1996       22
# ...           ...
# 9-9-1986       20
# 9-9-1994       21
# 9-9-2003       16
# 9-9-2009       16
# 9-9-2011       18
#
# [2757 rows x 1 columns]

# %%
x=a[(a["Country"]=="India")&(a["Player"]=="Sachin R Tendul")]

# %%
y=x.groupby("Player")["Runs"].sum()

# %%
y.sort_values(ascending=False)
# Out:
# Series([], Name: ScoreRate, dtype: float64)

# %%
a["date"]=pd.to_datetime(a["MatchDate"])
a["year"]=a["date"].dt.strftime('%y')
a["month"]=a["date"].dt.strftime('%m')
a["month-name"]=a["date"].dt.strftime('%b')
a["day"]=a["date"].dt.strftime('%d')
a["weekend"]=a["date"].dt.strftime('%A')
a[["date","year","month","month-name","day","weekend"]].head()
# Out:
#         date year month month-name day   weekend
# 0 2010-02-16   10    02        Feb  16   Tuesday
# 1 2009-09-01   09    09        Sep  01   Tuesday
# 2 2010-08-16   10    08        Aug  16    Monday
# 3 2010-07-10   10    07        Jul  10  Saturday
# 4 2010-07-01   10    07        Jul  01  Thursday

# %% [markdown]
# # pie chart

# %%
w=pd.read_csv("Documents/odi-batting.csv")

# %%
w["ScoreRate"].value_counts().head(10).plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='ScoreRate'>

# %% [markdown]
# # PIVOT

# %%
g=pd.read_csv("Documents/odi-batting.csv")
g.head()
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %%
p=g.pivot(index="Runs",columns=["Player","Country","MatchDate","Ground","Versus","URL"],values="ScoreRate")
p
# Out:
# Player                                    Mohammad Shahzad  \
# Country                                        Afghanistan
# MatchDate                                        2-16-2010
# Ground                                  Sharjah CA Stadium
# Versus                                              Canada
# URL       ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# Runs
# NaN                                                    NaN
# 0.0                                                    NaN
# 1.0                                                    NaN
# 2.0                                                    NaN
# 3.0                                                    NaN
# ..                                                     ...
# 186.0                                                  NaN
# 188.0                                                  NaN
# 189.0                                                  NaN
# 194.0                                                  NaN
# ...

# %%
top_10=g[g["Country"]=="India"]
top_10.pivot_table(index="Player",values="Runs",aggfunc=np.sum).sort_values(by="Runs",ascending=False).head(10)
# Out:
#                         Runs
# Player
# Sachin R Tendulkar   18111.0
# Sourav C Ganguly     11363.0
# Rahul Dravid         10889.0
# Mohammad Azharuddin   9378.0
# Yuvraj Singh          8051.0
# Virender Sehwag       7760.0
# Mahendra S Dhoni      6497.0
# Alaysinhji D Jadeja   5359.0
# Navjot S Sidhu        4413.0
# Gautam Gambhir        4286.0

# %% [markdown]
# # BOXPLOT

# %%
import seaborn as sns
sns.boxplot(x="Runs",y="MatchDate",data=g)
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='MatchDate'>

# %% [markdown]
# # MISSING VALUES

# %%
sns.heatmap(g.isna())
plt.show()

# %%
g.isna().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# ScoreRate    26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %%
count,bin_edges=np.histogram(g["Runs"].head(30))
g["Runs"].head(30).plot(kind="hist",xticks=bin_edges)
plt.xlabel("numbers of Runs")
plt.ylabel("highest score")
plt.grid()
plt.show()

# %%
g["Runs"].value_counts().head(10).plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x="Runs",y="ScoreRate",new="Runs",data=g)
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='ScoreRate'>

# %%
g["ScoreRate"].dtype
# Out:
# dtype('float64')

# %%
g["ScoreRate"].mean()
# Out:
# 65.31420805009037

# %%
g["ScoreRate"].value_counts()
# Out:
# 0.00      5616
# 100.00    2371
# 50.00     2103
# 33.33     1256
# 66.66     1151
#           ...
# 72.11        1
# 109.41       1
# 42.46        1
# 46.73        1
# 16.43        1
# Name: ScoreRate, Length: 4196, dtype: int64

# %%
g.isnull().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# ScoreRate    26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %%
g.iloc[g["Runs"].isna()]=25

# %%
g.iloc[g["ScoreRate"].isna()]=300

# %%
g.isnull().sum()
# Out:
# Country      0
# Player       0
# Runs         0
# ScoreRate    0
# MatchDate    0
# Ground       0
# Versus       0
# URL          0
# dtype: int64

# %%
sns.heatmap(g.isna())
plt.show()

# %% [markdown]
# # ANOVA(analysis of variance)

# %%
auto_temp1=g[["Ground","Runs"]]
group1=auto_temp1.groupby(["Ground"]).mean().sort_values(ascending=False,by="Runs")
group1
# Out:
#                                        Runs
# Ground
# Pukekura Park                     39.000000
# AC-VDCA Stadium                   35.425532
# Hove County Ground                31.000000
# Jawaharlal Nehru Stadium (Delhi)  30.666667
# Kwekwe Sports Club                30.642857
# ...                                     ...
# Grace Road                        14.927273
# Northampton County Ground         13.500000
# Devonport Oval                    13.454545
# Lavington Sports Oval             10.181818
# Harrup Park                        0.500000
#
# [179 rows x 1 columns]

# %%
g
# Out:
#            Country               Player   Runs  ScoreRate   MatchDate  \
# 0      Afghanistan     Mohammad Shahzad  118.0      97.52   2-16-2010
# 1      Afghanistan     Mohammad Shahzad  110.0      99.09    9-1-2009
# 2      Afghanistan     Mohammad Shahzad  100.0     138.88   8-16-2010
# 3      Afghanistan     Mohammad Shahzad   82.0      75.92   7-10-2010
# 4      Afghanistan     Mohammad Shahzad   57.0     100.00    7-1-2010
# ...            ...                  ...    ...        ...         ...
# 55921     Zimbabwe  Waddington Mwayenga    0.0       0.00   5-27-2004
# 55922     Zimbabwe   Tafadzwa Kamungozi    0.0       0.00  10-10-2006
# 55923     Zimbabwe   Tafadzwa Kamungozi    0.0       0.00   10-8-2006
# 55924     Zimbabwe   Tafadzwa Kamungozi    0.0       0.00  10-13-2006
# 55925     Zimbabwe        Njabulo Ncube    0.0       0.00  10-25-2011
#
#                        Ground       Versus  \
# 0          Sharjah CA Stadium       Canada
# ...

# %%
group1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Ground'>

# %%
temp_df=g[["Ground","Runs"]].groupby(["Ground"])
temp_df.head()
# Out:
#                       Ground   Runs
# 0         Sharjah CA Stadium  118.0
# 1                 VRA Ground  110.0
# 2      Cambusdoon New Ground  100.0
# 3                Hazelaarweg   82.0
# 4        Sportpark Westvliet   57.0
# ...                      ...    ...
# 43624             Berri Oval    3.0
# 44300     Tasmania CA Ground   27.0
# 44340     Tasmania CA Ground   56.0
# 44644     Tasmania CA Ground    8.0
# 45007     Tasmania CA Ground    8.0
#
# [892 rows x 2 columns]

# %%
stats.f_oneway(temp_df.get_group("VRA Ground")["Runs"],temp_df.get_group("Sportpark Westvliet")["Runs"])
# Out:
# F_onewayResult(statistic=0.1302927542977925, pvalue=0.7183202095175067)

# %%
g.isna().sum()
# Out:
# Country      0
# Player       0
# Runs         0
# ScoreRate    0
# MatchDate    0
# Ground       0
# Versus       0
# URL          0
# dtype: int64

# %% [markdown]
# # CORRELATION

# %%
i=pd.read_csv("Documents/odi-batting.csv")

# %%
c_m=i.corr()

# %%
plt.subplots(figsize=(10,15))
sns.heatmap(c_m,annot=True)
plt.show()

# %%
sns.regplot(x="Runs",y="ScoreRate",data=i)
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='ScoreRate'>
